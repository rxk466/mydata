# %% [markdown]
# ## WELLBEING SURVEY 2020 x YEAR IN SCHOOL

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
wb=pd.read_csv('ethsclean.csv')

# %%
wb['Smoke/Vape Electronic Cigarette']
# Out:
# 0                       Never
# 1                       Never
# 2                       Never
# 3                       Never
# 4                       Never
#                 ...
# 2550    Daily or almost daily
# 2551                    Never
# 2552                    Never
# 2553                    Never
# 2554                    Never
# Name: Smoke/Vape Electronic Cigarette, Length: 2555, dtype: object

# %% [markdown]
# ### Q1 How old are you?

# %%
age= pd.crosstab(index=wb['Age'], columns=wb['Year'], margins=True)
display(age)
# Out:
# Year                 Class of 2019 and earlier  Class of 2020- Seniors  \
# Age
# 14 years or younger                          1                       0
# 15 years old                                 1                       1
# 16 years old                                 0                       3
# 17 years old                                 1                     248
# 18 years or older                            2                     240
# All                                          5                     492
#
# Year                 Class of 2021- Juniors  Class of 2022- Sophomores  \
# Age
# 14 years or younger                       0                          1
# 15 years old                              0                        336
# 16 years old                            336                        318
# 17 years old                            314                          4
# 18 years or older                        11                          0
# ...

# %%
racea=pd.crosstab(index=wb['African-American/Black'], columns=wb['Year'])
racei=pd.crosstab(index=wb['American Indian/Alaskan Native'], columns=wb['Year'])
raceas=pd.crosstab(index=wb['Asian American'], columns=wb['Year'])
raceh=pd.crosstab(index=wb['Native Hawaiian/Other Pacific I'], columns=wb['Year'])
racetwoplus=pd.crosstab(index=wb['Two or more races'], columns=wb['Year'])
racew=pd.crosstab(index=wb['White'], columns=wb['Year'])

# %% [markdown]
# ### Q4 What is your race?

# %%
race_stack = pd.concat([racea,racei,raceas,raceh,racetwoplus,racew], axis=0)
race_stack
# Out:
#                                         Class of 2020- Seniors  \
# African-American/Black                                     120
# American Indian/Alaskan Native                               5
# Asian American                                              34
# Native Hawaiian/Other Pacific Islander                       7
# Two or more races                                           38
# White                                                      280
#
#                                         Class of 2021- Juniors  \
# African-American/Black                                     164
# American Indian/Alaskan Native                              12
# Asian American                                              45
# Native Hawaiian/Other Pacific Islander                      12
# Two or more races                                           67
# White                                                      394
#
#                                         Class of 2022- Sophomores  \
# ...

# %% [markdown]
# #### Other

# %%
raceo=pd.crosstab(index=wb['Other (please specify)'], columns=wb['Year'], margins=True)
raceo
# Out:
# Year                         Class of 2019 and earlier  \
# Other (please specify)
# African-American & Filipino                          0
# Afro Caribbean                                       0
# Afro-latina                                          0
# Afro-latina                                          0
# American Mexican                                     0
# ...                                                ...
# salvadorian                                          0
# swedish american                                     0
# white indigenous                                     0
# white mixed with asian                               0
# All                                                  1
#
# Year                         Class of 2020- Seniors  Class of 2021- Juniors  \
# Other (please specify)
# African-American & Filipino                       0                       0
# Afro Caribbean                                    1                       0
# ...

# %% [markdown]
# ### Q5 What is your gender identity?

# %%
gender=pd.crosstab(index=wb['Response_3'], columns=wb['Year'], margins=True)
gender=gender.drop(['Class of 2019 and earlier'], axis=1)
gender.columns=['Seniors','Juniors','Sophomores','Freshmen','coltot']
gender
# Out:
#                                                     Seniors  Juniors  \
# Response_3
# Female                                                  266      301
# Male                                                    210      346
# Nonbinary: a person who does not identify as ex...        7        8
# Other (please specify)                                    3        1
# Transgender: an umbrella term that may be used ...        4        4
# All                                                     490      660
#
#                                                     Sophomores  Freshmen  \
# Response_3
# Female                                                     327       364
# Male                                                       317       351
# Nonbinary: a person who does not identify as ex...           7         7
# Other (please specify)                                       3         4
# Transgender: an umbrella term that may be used ...           5         5
# ...

# %% [markdown]
# ### Q6 Which of the following best describes your sexual orientation?

# %%
sexo=pd.crosstab(index=wb['Response_4'], columns=wb['Year'], margins=True)
sexo=sexo.drop(['Class of 2019 and earlier'], axis=1)
sexo.columns=['Seniors','Juniors','Sophomores','Freshmen','coltot']
sexo
# Out:
#                                                     Seniors  Juniors  \
# Response_4
# Asexual: a person who does not experience sexua...       15       14
# Bisexual                                                 43       83
# Heterosexual/straight                                   379      498
# Homosexual/gay or lesbian                                19       20
# Not sure/questioning                                     20       19
# Other (please specify)                                   14       20
# All                                                     490      654
#
#                                                     Sophomores  Freshmen  \
# Response_4
# Asexual: a person who does not experience sexua...          18        21
# Bisexual                                                    56        59
# Heterosexual/straight                                      513       568
# Homosexual/gay or lesbian                                   20        28
# ...

# %% [markdown]
# #### Other

# %%
sexot=pd.crosstab(index=wb['Other (please specify)_2'], columns=wb['Year'], margins=True)
sexot.columns=['Seniors','Juniors','Sophomores','Freshmen','coltot']
sexot
# Out:
#                                                     Seniors  Juniors  \
# Other (please specify)_2
# .                                                         0        0
# ... idk XD                                                0        1
# Aromantic and Asexual                                     0        1
# BiFlexual                                                 0        0
# Deciding between Pansexual or Asexual                     0        0
# Demisexual                                                0        1
# Demisexual                                                0        1
# Demisexual, I only feel sexual ataction for one...        0        1
# Heteroromantic Bisexual                                   0        0
# I choose not to define my sexuality                       1        0
# I like girl.                                              0        0
# I'm sort of figuring it out as I go along                 1        0
# ...

# %% [markdown]
# ### Q2 What year are you in school?

# %%
year= pd.crosstab(index=wb['Year'], columns='count')
year
yearedit=year.drop(['Class of 2019 and earlier'], axis=0)
yearedit
# Out:
# col_0                      count
# Year
# Class of 2020- Seniors       492
# Class of 2021- Juniors       662
# Class of 2022- Sophomores    659
# Class of 2023- Freshmen      732

# %% [markdown]
# ### Q7 Are you currently enrolled in the free/reduced lunch program at school?

# %%
lunchp= pd.crosstab(index=wb['Lunch Program'], columns=wb['Year'], margins=True)
lunchp
# Out:
# Year           Class of 2019 and earlier  Class of 2020- Seniors  \
# Lunch Program
# Don't know                             0                      30
# No                                     4                     324
# Yes                                    1                     138
# All                                    5                     492
#
# Year           Class of 2021- Juniors  Class of 2022- Sophomores  \
# Lunch Program
# Don't know                         33                         45
# No                                455                        449
# Yes                               174                        164
# All                               662                        658
#
# Year           Class of 2023- Freshmen   All
# Lunch Program
# Don't know                         118   226
# No                                 449  1681
# Yes                                165   642
# All                                732  2549

# %% [markdown]
# ### Q8 Do you have a job?

# %%
job= pd.crosstab(index=wb['Job'], columns=wb['Year'], margins=True)
job
# Out:
# Year  Class of 2019 and earlier  Class of 2020- Seniors  \
# Job
# No                            1                     246
# Yes                           4                     246
# All                           5                     492
#
# Year  Class of 2021- Juniors  Class of 2022- Sophomores  \
# Job
# No                       405                        496
# Yes                      256                        163
# All                      661                        659
#
# Year  Class of 2023- Freshmen   All
# Job
# No                        623  1771
# Yes                       108   777
# All                       731  2548

# %%
def wrongforpeersto(name):
    name=pd.crosstab(index=wb[name],columns=wb['Year'],margins=True)
    name=name.drop(['Class of 2019 and earlier'], axis=1)
    name.columns=['Seniors','Juniors','Sophomores','Freshmen','coltot']
    name.index=['A little wrong','Not at all','Somewhat wrong','Very wrong','Wrong','rowtot']
    name=name.reindex(['Not at all', 'A little wrong','Somewhat wrong','Wrong','Very wrong','rowtot'])
    display(name)

# %% [markdown]
# ### Q68 To what extent do you think it is wrong for someone your age to:

# %% [markdown]
# #### Drink beer, wine or hard liquor (at least once or twice per month)?

# %%
wrongforpeersto('Drink beer, wine or hard liquor')
# Out:
#                 Seniors  Juniors  Sophomores  Freshmen  coltot
# Not at all          194      204         143       109     653
# A little wrong      122      177         154       130     583
# Somewhat wrong       68      121         136       118     444
# Wrong                61       85         130       192     468
# Very wrong           44       71          94       180     390
# rowtot              489      658         657       729    2538

# %% [markdown]
# #### Use cannabis (marijuana)?

# %%
wrongforpeersto('Use cannabis (marijuana)?')
# Out:
#                 Seniors  Juniors  Sophomores  Freshmen  coltot
# Not at all          219      227         162       118     729
# A little wrong      123      174         130       132     559
# Somewhat wrong       58       99         146       127     431
# Wrong                48       92         119       153     412
# Very wrong           42       65         100       198     406
# rowtot              490      657         657       728    2537

# %% [markdown]
# #### Smoke cigarettes?

# %%
wrongforpeersto('Smoke cigarettes?')
# Out:
#                 Seniors  Juniors  Sophomores  Freshmen  coltot
# Not at all           59       59          59        66     245
# A little wrong       24       36          29        18     107
# Somewhat wrong       51       69          43        43     206
# Wrong               135      143         172       168     619
# Very wrong          217      334         336       425    1314
# rowtot              486      641         639       720    2491

# %% [markdown]
# #### Use E-cigarettes or other vaping devices?

# %%
wrongforpeersto('Use E-cigarettes or other vapin')
# Out:
#                 Seniors  Juniors  Sophomores  Freshmen  coltot
# Not at all           64       73          75        75     289
# A little wrong       50       81          59        41     232
# Somewhat wrong       83       97          96        91     367
# Wrong               141      178         189       208     717
# Very wrong          151      224         237       313     926
# rowtot              489      653         656       728    2531

# %% [markdown]
# #### Use prescription drugs not prescribed to them?

# %%
wrongforpeersto('Use prescription drugs not pres')
# Out:
#                 Seniors  Juniors  Sophomores  Freshmen  coltot
# Not at all           52       58          64        73     249
# A little wrong       14       21          15        14      65
# Somewhat wrong       42       55          43        57     197
# Wrong                94      124         128       159     505
# Very wrong          288      396         408       425    1519
# rowtot              490      654         658       728    2535

# %%
def parentsthinkitswrong(name):
    name=pd.crosstab(index=wb[name],columns=wb['Year'],margins=True)
    name=name.drop(['Class of 2019 and earlier'], axis=1)
    name.columns=['Seniors','Juniors','Sophomores','Freshmen','coltot']
    name.index=['A little wrong','Not at all','Somewhat wrong','Very wrong','Wrong','rowtot']
    name=name.reindex(['Not at all', 'A little wrong','Somewhat wrong','Wrong','Very wrong','rowtot'])
    display(name)

# %% [markdown]
# ### Q69 To what extent do your parent(s)/guardian(s) think it is wrong for someone your age to:

# %% [markdown]
# #### Drink beer, wine or hard liquor (at least once or twice per month)?

# %%
parentsthinkitswrong('Drink beer, wine or hard liqu_1')
# Out:
#                 Seniors  Juniors  Sophomores  Freshmen  coltot
# Not at all           55       60          44        50     211
# A little wrong      104       86          56        38     284
# Somewhat wrong       86      115          84        79     364
# Wrong                98      149         173       150     571
# Very wrong          143      248         300       413    1106
# rowtot              486      658         657       730    2536

# %% [markdown]
# #### Use cannabis (marijuana)?

# %%
parentsthinkitswrong('Use cannabis (marijuana)?_1')
# Out:
#                 Seniors  Juniors  Sophomores  Freshmen  coltot
# Not at all           53       49          41        39     184
# A little wrong       69       57          38        28     192
# Somewhat wrong       75       96          58        58     287
# Wrong               111      145         154       120     531
# Very wrong          180      311         366       484    1343
# rowtot              488      658         657       729    2537

# %% [markdown]
# #### Smoke cigarettes?

# %%
parentsthinkitswrong('Smoke cigarettes?_1')
# Out:
#                 Seniors  Juniors  Sophomores  Freshmen  coltot
# Not at all           27       26          24        30     109
# A little wrong        9        3           4         5      21
# Somewhat wrong       21       21           9         8      59
# Wrong                82       84          89        67     322
# Very wrong          343      520         526       609    2001
# rowtot              482      654         652       719    2512

# %% [markdown]
# #### Use E-cigarettes or other vaping devices?

# %%
parentsthinkitswrong('Use E-cigarettes or other vap_1')
# Out:
#                 Seniors  Juniors  Sophomores  Freshmen  coltot
# Not at all           28       29          26        32     117
# A little wrong        8        5           4         8      25
# Somewhat wrong       28       22          20        21      91
# Wrong                82       92          96        80     350
# Very wrong          342      510         512       589    1956
# rowtot              488      658         658       730    2539

# %% [markdown]
# #### Use prescription drugs not prescribed to them?

# %%
parentsthinkitswrong('Use prescription drugs not pr_1')
# Out:
#                 Seniors  Juniors  Sophomores  Freshmen  coltot
# Not at all           29       28          26        34     119
# A little wrong        6        1           4         7      18
# Somewhat wrong       14       11           6        15      46
# Wrong                57       55          63        64     239
# Very wrong          380      562         555       605    2105
# rowtot              486      657         654       725    2527

# %%
def riskharming(name):
    name=pd.crosstab(index=wb[name],columns=wb['Year'],margins=True)
    name=name.drop(['Class of 2019 and earlier'], axis=1)
    name.columns=['Seniors','Juniors','Sophomores','Freshmen','coltot']
    name.index=['A great deal','A little','A lot','A moderate amount','Not at all','rowtot']
    name=name.reindex(['Not at all', 'A little','A moderate amount','A lot','A great deal','rowtot'])
    display(name)

# %% [markdown]
# ## Q70 How much do you think people risk harming themselves (physically or in other ways) if they:

# %% [markdown]
# #### Smoke one or more packs of cigarettes per day?

# %%
riskharming('Smoke one or more packs of ciga')
# Out:
#                    Seniors  Juniors  Sophomores  Freshmen  coltot
# Not at all              34       49          34        37     155
# A little                21       28          33        47     129
# A moderate amount       51       50          66        77     244
# A lot                   95      107         154       144     502
# A great deal           289      423         370       421    1505
# rowtot                 490      657         657       726    2535

# %% [markdown]
# #### Use E-cigarettes or other vaping devices?

# %%
riskharming('Use E-cigarettes or other vapin')
# Out:
#                    Seniors  Juniors  Sophomores  Freshmen  coltot
# Not at all              38       48          37        39     163
# A little                41       53          67        61     223
# A moderate amount       88      108         128       127     453
# A lot                  141      180         198       207     726
# A great deal           181      266         227       292     967
# rowtot                 489      655         657       726    2532

# %% [markdown]
# #### Take one or two drinks of an alcoholic beverage nearly every day?

# %%
riskharming('Take one or two drinks of an al')
# Out:
#                    Seniors  Juniors  Sophomores  Freshmen  coltot
# Not at all              35       45          33        40     154
# A little                54       43          68        73     239
# A moderate amount       93      127         106       128     456
# A lot                  120      189         202       198     709
# A great deal           183      249         247       286     966
# rowtot                 485      653         656       725    2524

# %% [markdown]
# #### Have five or more drinks of an alcoholic beverage once or twice a week?

# %%
riskharming('Have five or more drinks of an')
# Out:
#                    Seniors  Juniors  Sophomores  Freshmen  coltot
# Not at all              37       50          32        40     160
# A little                45       40          49        52     187
# A moderate amount       93      106         113       107     420
# A lot                  122      163         180       186     651
# A great deal           190      294         281       338    1104
# rowtot                 487      653         655       723    2522

# %% [markdown]
# #### Use cannabis (marijuana) once or twice a week?

# %%
riskharming('Use cannabis (marijuana) once o')
# Out:
#                    Seniors  Juniors  Sophomores  Freshmen  coltot
# Not at all             118      152          94        83     450
# A little               150      161         163       138     612
# A moderate amount      103      137         162       166     569
# A lot                   61      100         132       147     441
# A great deal            54      106         104       185     449
# rowtot                 486      656         655       719    2521

# %% [markdown]
# #### Use prescription drugs not prescribed to them?

# %%
riskharming('Use prescription drugs not pr_2')
# Out:
#                    Seniors  Juniors  Sophomores  Freshmen  coltot
# Not at all              28       39          31        38     137
# A little                25       25          36        45     133
# A moderate amount       52       60          51        86     249
# A lot                  103      135         138       167     544
# A great deal           278      398         397       388    1462
# rowtot                 486      657         653       724    2525

# %%
def seenascool(name):
    name=pd.crosstab(index=wb[name],columns=wb['Year'],margins=True)
    name=name.drop(['Class of 2019 and earlier'], axis=1)
    name.columns=['Seniors','Juniors','Sophomores','Freshmen','coltot']
    name.index=['A little chance','Good chance','No chance','Some chance','Very good chance','All']
    name=name.reindex(['No chance','A little chance','Some chance','Good chance','Very good chance','All'])
   
    display(name)

# %% [markdown]
# ### Q71 What are the chances you would be seen as cool if you:

# %% [markdown]
# #### Smoked cigarettes?

# %%
seenascool('Smoked cigarettes?')
# Out:
#                   Seniors  Juniors  Sophomores  Freshmen  coltot
# No chance             314      429         418       469    1635
# A little chance       101      120         128       124     473
# Some chance            32       52          54        71     209
# Good chance            16       28          32        34     110
# Very good chance       12       15          10        11      48
# All                   475      644         642       709    2475

# %% [markdown]
# #### Used E-cigarettes or other vaping devices?

# %%
seenascool('Used E-cigarettes or other vapi')
# Out:
#                   Seniors  Juniors  Sophomores  Freshmen  coltot
# No chance             194      255         230       314     997
# A little chance       118      166         161       146     591
# Some chance            96      109         135       133     473
# Good chance            53       86          90        96     326
# Very good chance       25       36          39        33     133
# All                   486      652         655       722    2520

# %% [markdown]
# #### Began drinking alcohol regularly, that is at least once or twice a month?

# %%
seenascool('Began drinking alcohol regularl')
# Out:
#                   Seniors  Juniors  Sophomores  Freshmen  coltot
# No chance             185      231         232       329     981
# A little chance        84      136         137       139     496
# Some chance            96      141         140       139     516
# Good chance            84      109         104        89     387
# Very good chance       37       38          42        29     146
# All                   486      655         655       725    2526

# %% [markdown]
# #### Used cannabis (marijuana)?

# %%
seenascool('Used cannabis (marijuana)?')
# Out:
#                   Seniors  Juniors  Sophomores  Freshmen  coltot
# No chance             158      181         192       260     795
# A little chance        70      123         106       145     444
# Some chance           103      122         147       133     505
# Good chance           101      137         134       123     496
# Very good chance       52       91          77        61     281
# All                   484      654         656       722    2521

# %% [markdown]
# #### Used prescription drugs not prescribed to you?

# %%
seenascool('Used prescription drugs not pre')
# Out:
#                   Seniors  Juniors  Sophomores  Freshmen  coltot
# No chance             300      394         371       444    1513
# A little chance        96      134         151       139     520
# Some chance            56       77          78        83     294
# Good chance            19       31          39        38     128
# Very good chance       15       18          17        21      71
# All                   486      654         656       725    2526

# %%
def useperception(name):
    name=pd.crosstab(index=wb[name],columns=wb['Year'],margins=True)
    name=name.drop(['Class of 2019 and earlier'], axis=1)
    name.columns=['Seniors','Juniors','Sophomores','Freshmen','coltot']
    name.index=['0-10%','11-25%','26-50%','51-75%','76-90%','91-100%','rowtot']
   
    display(name)

# %% [markdown]
# ### Q72 During the past 30 days, approximately what percent of students in your school do you think did the following:

# %% [markdown]
# #### Smoked cigarettes?

# %%
useperception('Smoked cigarettes?_1')
# Out:
#          Seniors  Juniors  Sophomores  Freshmen  coltot
# 0-10%        234      309         311       343    1200
# 11-25%       133      198         201       177     710
# 26-50%        63       78          74       102     317
# 51-75%        22       38          40        56     156
# 76-90%        15       13           9        24      61
# 91-100%        9       10           8         2      30
# rowtot       476      646         643       704    2474

# %% [markdown]
# #### Used E-cigarettes or other vaping devices?

# %%
useperception('Used E-cigarettes or other va_1')
# Out:
#          Seniors  Juniors  Sophomores  Freshmen  coltot
# 0-10%         35       48          27        48     161
# 11-25%        37       52          81       113     283
# 26-50%       138      173         179       197     687
# 51-75%       136      198         185       194     713
# 76-90%       105      134         143       146     528
# 91-100%       37       51          41        22     153
# rowtot       488      656         656       720    2525

# %% [markdown]
# #### Had at least one drink of alcohol (not including drinking a few sips of wine for religious purposes)?

# %%
useperception('Had at least one drink of alcoh')
# Out:
#          Seniors  Juniors  Sophomores  Freshmen  coltot
# 0-10%         39       57          43       102     244
# 11-25%        37       58          90       150     335
# 26-50%        87      166         183       161     597
# 51-75%       159      176         161       169     665
# 76-90%       117      146         130       108     501
# 91-100%       47       52          50        30     181
# rowtot       486      655         657       720    2523

# %% [markdown]
# #### Used cannabis (marijuana)?

# %%
useperception('Used cannabis (marijuana)?_1')
# Out:
#          Seniors  Juniors  Sophomores  Freshmen  coltot
# 0-10%         35       45          38        82     203
# 11-25%        38       66          98       139     341
# 26-50%       112      143         179       182     616
# 51-75%       135      191         155       150     631
# 76-90%       105      133         131       116     485
# 91-100%       62       77          53        49     243
# rowtot       487      655         654       718    2519

# %% [markdown]
# #### Used someone else's prescription drugs?

# %%
useperception('Used someone else_s prescriptio')
# Out:
#          Seniors  Juniors  Sophomores  Freshmen  coltot
# 0-10%        206      291         262       302    1064
# 11-25%       159      208         205       198     770
# 26-50%        67       88         113       116     384
# 51-75%        25       37          46        65     173
# 76-90%        18       14          20        31      84
# 91-100%       12       18          11         5      47
# rowtot       487      656         657       717    2522

# %%
def thirtydayuse(name):
    name=pd.crosstab(index=wb[name],columns=wb['Year'],margins=True)
    name=name.drop(['Class of 2019 and earlier'], axis=1)
    name.columns=['Seniors','Juniors','Sophomores','Freshmen','coltot']
    
    display(name)

# %% [markdown]
# ### Q73 In the past 30 days, how often did you...

# %% [markdown]
# #### Drink one or more alcoholic beverages?

# %%
thirtydayuse('Drink one or more alcoholic bev')
# Out:
#                                  Seniors  Juniors  Sophomores  Freshmen  \
# Drink one or more alcoholic bev
# Daily or almost daily                  5        2           1         2
# Never                                253      416         486       584
# Often                                 29       21          15         6
# Rarely                                81      118          98        87
# Sometimes                            122       99          57        43
# All                                  490      656         657       722
#
#                                  coltot
# Drink one or more alcoholic bev
# Daily or almost daily                12
# Never                              1742
# Often                                71
# Rarely                              384
# Sometimes                           321
# All                                2530

# %% [markdown]
# #### Drink five or more alcoholic drinks in a row?

# %%
thirtydayuse('Drink five or more alcoholic dr')
# Out:
#                     Seniors  Juniors  Sophomores  Freshmen  coltot
# Never                   346      538         579       684    2150
# Rarely                   80       56          42        17     195
# Sometimes                46       48          26        19     139
# Often                    14       11           8         0      33
# Daily/almost daily        4        1           1         2      10
# rowtot                  490      654         656       722    2527

# %% [markdown]
# #### Use tobacco products (cigarettes, cigars, hookah, etc.)?

# %%
thirtydayuse('Use tobacco products (cigarette')
# Out:
#                     Seniors  Juniors  Sophomores  Freshmen  coltot
# Never                   438      614         629       696    2380
# Rarely                   28       23          14        16      81
# Sometimes                12        5           5         6      28
# Often                     6        7           2         2      17
# Daily/almost daily        6        4           3         2      17
# rowtot                  490      653         653       722    2523

# %% [markdown]
# #### Smoke/Vape Electronic Cigarettes?

# %%
thirtydayuse('Smoke/Vape Electronic Cigarette')
# Out:
#                     Seniors  Juniors  Sophomores  Freshmen  coltot
# Never                   381      521         559       661    2125
# Rarely                   43       63          40        33     179
# Sometimes                29       44          27        22     122
# Often                    15       13          14         4      46
# Daily/almost daily       16       14          17         3      52
# rowtot                  484      655         657       723    2524

# %% [markdown]
# #### Use cannabis (marijuana)?

# %%
thirtydayuse('Use cannabis (marijuana)?_2')
# Out:
#                     Seniors  Juniors  Sophomores  Freshmen  coltot
# Never                   297      444         503       615    1862
# Rarely                   56       67          48        52     223
# Sometimes                54       62          44        34     194
# Often                    35       42          31        10     118
# Daily/almost daily       43       33          21         5     104
# rowtot                  485      648         647       716    2501

# %% [markdown]
# #### Use prescription drugs that were prescribed to you to get high?

# %%
thirtydayuse('Use prescription drugs that wer')
# Out:
#                     Seniors  Juniors  Sophomores  Freshmen  coltot
# Never                   472      634         643       703    2455
# Rarely                    4       11           8         4      27
# Sometimes                 5        4           2        11      22
# Often                     3        3           2         3      11
# Daily/almost daily        4        3           2         2      13
# rowtot                  488      655         657       723    2528

# %% [markdown]
# #### Use prescription drugs NOT prescribed to you to get high?

# %%
thirtydayuse('Use prescription drugs NOT pr_3')
# Out:
#                     Seniors  Juniors  Sophomores  Freshmen  coltot
# Never                   467      631         640       697    2438
# Rarely                    6       12           8         8      34
# Sometimes                 7        4           5         9      25
# Often                     4        2           3         3      12
# Daily/almost daily        4        3           1         3      13
# rowtot                  488      652         657       720    2522

# %%
def thirtydayalctype(name):
    name=pd.crosstab(index=wb[name],columns=wb['Year'],margins=True)
    name=name.drop(['Class of 2019 and earlier'], axis=1)
    name.columns=['Seniors','Juniors','Sophomores','Freshmen','coltot']
    name.index=['Daily/almost daily','Never','Often','Rarely','Sometimes','rowtot']
    name=name.reindex(['Never','Rarely','Sometimes','Often','Daily/almost daily','rowtot'])
   
    display(name)

# %% [markdown]
# ## Q74 In the past 30 days, how often did you drink any of the following types of alcohol:

# %% [markdown]
# #### Beer

# %%
thirtydayalctype('Beer')
# Out:
#                     Seniors  Juniors  Sophomores  Freshmen  coltot
# Never                   333      504         554       643    2037
# Rarely                   65       80          63        56     264
# Sometimes                70       55          30        20     175
# Often                    15       14           8         0      37
# Daily/almost daily        4        2           0         2      10
# rowtot                  487      655         655       721    2523

# %% [markdown]
# #### Wine

# %%
thirtydayalctype('Wine')
# Out:
#                     Seniors  Juniors  Sophomores  Freshmen  coltot
# Never                   352      533         557       620    2065
# Rarely                   74       78          69        65     286
# Sometimes                54       29          22        20     125
# Often                     4        7           7         5      23
# Daily/almost daily        4        1           0         3      10
# rowtot                  488      648         655       713    2509

# %% [markdown]
# #### Hard Liquor

# %%
thirtydayalctype('Hard Liquor')
# Out:
#                     Seniors  Juniors  Sophomores  Freshmen  coltot
# Never                   289      471         520       636    1919
# Rarely                   80       78          63        36     257
# Sometimes                84       65          35        27     211
# Often                    23       20          19         4      66
# Daily/almost daily        6        3           1         2      14
# rowtot                  482      637         638       705    2467

# %% [markdown]
# #### Alcopops (e.g. Mike's Lemonade,Smirnoff Ice)

# %%
thirtydayalctype('Alcopops (e.g. Mike_s Lemonade,')
# Out:
#                     Seniors  Juniors  Sophomores  Freshmen  coltot
# Never                   374      529         568       665    2139
# Rarely                   46       58          33        32     169
# Sometimes                52       51          37        16     156
# Often                    13       14          16         6      49
# Daily/almost daily        4        1           2         2      11
# rowtot                  489      653         656       721    2524

# %% [markdown]
# #### Liquor with energy drinks

# %%
thirtydayalctype('Liquor with energy drinks')
# Out:
#                     Seniors  Juniors  Sophomores  Freshmen  coltot
# Never                   444      602         619       690    2358
# Rarely                   23       24          23        20      90
# Sometimes                14       19           4         4      41
# Often                     2        3           9         4      18
# Daily/almost daily        4        2           1         3      12
# rowtot                  487      650         656       721    2519

# %%
def thirtydaycantype(name):
    name=pd.crosstab(index=wb[name],columns=wb['Year'],margins=True)
    name=name.drop(['Class of 2019 and earlier'], axis=1)
    name.columns=['Seniors','Juniors','Sophomores','Freshmen','coltot']
    name.index=['Daily/almost daily','Never','Often','Rarely','Sometimes','rowtot']
    name=name.reindex(['Never','Rarely','Sometimes','Often','Daily/almost daily','rowtot'])
   
    display(name)

# %% [markdown]
# ## Q75 In the past 30 days, how often did you use cannabis (marijuana) in any of the following ways:

# %% [markdown]
# #### Smoked It

# %%
thirtydaycantype('Smoked it')
# Out:
#                     Seniors  Juniors  Sophomores  Freshmen  coltot
# Never                   314      469         524       636    1946
# Rarely                   48       53          45        42     188
# Sometimes                49       62          45        24     180
# Often                    35       42          31        12     120
# Daily/almost daily       42       28           8         6      86
# rowtot                  488      654         653       720    2520

# %% [markdown]
# #### Vaporized It

# %%
thirtydaycantype('Vaporized it')
# Out:
#                     Seniors  Juniors  Sophomores  Freshmen  coltot
# Never                   383      513         566       652    2117
# Rarely                   32       58          29        29     148
# Sometimes                36       42          24        24     126
# Often                    18       25          20        10      73
# Daily/almost daily       16       14           9         2      43
# rowtot                  485      652         648       717    2507

# %% [markdown]
# #### Ate It

# %%
thirtydaycantype('Ate it')
# Out:
#                     Seniors  Juniors  Sophomores  Freshmen  coltot
# Never                   398      557         576       671    2205
# Rarely                   50       55          33        33     171
# Sometimes                23       27          20         7      77
# Often                     7        9          17         1      34
# Daily/almost daily        8        4           3         4      21
# rowtot                  486      652         649       716    2508

# %% [markdown]
# #### Consumed it some other way

# %%
thirtydaycantype('Consumed it some other way')
# Out:
#                     Seniors  Juniors  Sophomores  Freshmen  coltot
# Never                   447      627         624       691    2391
# Rarely                   14       12           6        12      44
# Sometimes                10        3           7         4      24
# Often                     7        1           6         1      15
# Daily/almost daily        8        6           2         4      22
# rowtot                  486      649         645       712    2496

# %%
def driveoride(name):
    name=pd.crosstab(index=wb[name],columns=wb['Year'],margins=True)
    name=name.drop(['Class of 2019 and earlier'], axis=1)
    name.columns=['Seniors','Juniors','Sophomores','Freshmen','coltot']
    name.index=['1-2 times','10-19 times','20+ times','3-9 times','Never','rowtot']
   
    display(name)

# %% [markdown]
# ## Q76 In the past 30 days, did you ever drive a car while under the influence of drugs or alcohol or ride in a car driven by someone else under the influence?

# %%
driveoride('Drive or Ride UI')
# Out:
#              Seniors  Juniors  Sophomores  Freshmen  coltot
# 1-2 times         42       56          36        23     157
# 10-19 times       13        4           4         4      25
# 20+ times         15        7           4         3      30
# 3-9 times         19       18           8         2      47
# Never            401      568         603       692    2268
# rowtot           490      653         655       724    2527

# %%
def yearuse(name):
    name=pd.crosstab(index=wb[name],columns=wb['Year'],margins=True)
    name=name.drop(['Class of 2019 and earlier'], axis=1)
    name.columns=['Seniors','Juniors','Sophomores','Freshmen','coltot']
    name.index=['Daily/almost daily','Never','Often','Rarely','Sometimes','rowtot']
    name=name.reindex(['Never','Rarely','Sometimes','Often','Daily/almost daily','rowtot'])
   
    display(name)

# %% [markdown]
# ## Q77 In the past YEAR, how often did you use...

# %% [markdown]
# #### Steroid pills or shots not prescribed to you?

# %%
yearuse('steroid pills or shots not pres')
# Out:
#                     Seniors  Juniors  Sophomores  Freshmen  coltot
# Never                   481      654         653       718    2510
# Rarely                    2        0           0         4       6
# Sometimes                 1        0           2         4       7
# Often                     1        0           0         0       1
# Daily/almost daily        4        2           1         0       8
# rowtot                  489      656         656       726    2532

# %% [markdown]
# #### Inhalants

# %%
yearuse('inhalants?')
# Out:
#                     Seniors  Juniors  Sophomores  Freshmen  coltot
# Never                   474      640         642       713    2473
# Rarely                    4        7           6         7      24
# Sometimes                 3        5           4         3      15
# Often                     2        2           3         2       9
# Daily/almost daily        4        3           1         1      10
# rowtot                  487      657         656       726    2531

# %% [markdown]
# #### hallucinogens/psychedelics?

# %%
yearuse('hallucinogens/psychedelics?')
# Out:
#                     Seniors  Juniors  Sophomores  Freshmen  coltot
# Never                   444      609         625       710    2391
# Rarely                   22       25          15         7      69
# Sometimes                14       13          10         3      40
# Often                     4        6           1         3      14
# Daily/almost daily        4        2           1         0       9
# rowtot                  488      655         652       723    2523

# %% [markdown]
# #### synthetic drugs?

# %%
yearuse('synthetic drugs?')
# Out:
#                     Seniors  Juniors  Sophomores  Freshmen  coltot
# Never                   477      640         635       717    2473
# Rarely                    1        8           8         3      20
# Sometimes                 3        3           4         3      13
# Often                     3        2           2         0       7
# Daily/almost daily        4        2           1         1       9
# rowtot                  488      655         650       724    2522

# %% [markdown]
# #### MDMA (Ecstasy)?

# %%
yearuse('MDMA (Ecstasy)?')
# Out:
#                     Seniors  Juniors  Sophomores  Freshmen  coltot
# Never                   462      637         648       711    2462
# Rarely                   12       12           3         4      31
# Sometimes                 8        2           0         3      13
# Often                     1        4           2         3      10
# Daily/almost daily        4        1           1         1       8
# rowtot                  487      656         654       722    2524

# %% [markdown]
# #### cocaine or crack?

# %%
yearuse('cocaine or crack?')
# Out:
#                     Seniors  Juniors  Sophomores  Freshmen  coltot
# Never                   465      639         652       719    2479
# Rarely                   13        9           0         1      23
# Sometimes                 5        3           1         2      11
# Often                     0        3           0         1       4
# Daily/almost daily        6        1           2         2      12
# rowtot                  489      655         655       725    2529

# %% [markdown]
# #### meth?

# %%
yearuse('meth?')
# Out:
#                     Seniors  Juniors  Sophomores  Freshmen  coltot
# Never                   478      651         652       720    2505
# Rarely                    3        3           1         2       9
# Sometimes                 2        0           0         2       4
# Often                     1        1           0         0       2
# Daily/almost daily        5        1           1         2      10
# rowtot                  489      656         654       726    2530

# %% [markdown]
# #### heroin?

# %%
yearuse('heroin?')
# Out:
#                     Seniors  Juniors  Sophomores  Freshmen  coltot
# Never                   480      654         653       719    2510
# Rarely                    3        0           0         0       3
# Sometimes                 1        0           0         2       3
# Often                     0        2           1         1       4
# Daily/almost daily        5        1           2         1      10
# rowtot                  489      657         656       723    2530

# %%
def firstusegrade(name):
    name=pd.crosstab(index=wb[name],columns=wb['Year'],margins=True)
    name=name.drop(['Class of 2019 and earlier'], axis=1)
    name.columns=['Seniors','Juniors','Sophomores','Freshmen','coltot']
    name.index=['Freshman/Sophomore year','Elementary school','Middle/Junior high school','Junior/Senior year','Never','rowtot']
   
    display(name)

# %% [markdown]
# ## Q78 What grade were you in when you first:

# %% [markdown]
# #### Used cannabis(marijuana)?

# %%
firstusegrade('Used cannabis (marijuana)?_2')
# Out:
#                            Seniors  Juniors  Sophomores  Freshmen  coltot
# Freshman/Sophomore year        145      191         136        54     526
# Elementary school                9        3           4         3      20
# Middle/Junior high school       36       64          56        72     229
# Junior/Senior year              76       48           0         0     124
# Never                          221      352         461       595    1632
# rowtot                         487      658         657       724    2531

# %% [markdown]
# #### Used an E-cigarette or other vaping device?

# %%
firstusegrade('Used an E-cigarette or other va')
# Out:
#                            Seniors  Juniors  Sophomores  Freshmen  coltot
# Freshman/Sophomore year        131      203         117        22     473
# Elementary school                4        4           2         6      17
# Middle/Junior high school       26       48          78       102     255
# Junior/Senior year              60       23           0         0      83
# Never                          267      379         459       595    1703
# rowtot                         488      657         656       725    2531

# %% [markdown]
# #### Smoked a cigarette, even just a puff?

# %%
firstusegrade('Smoked a cigarette, even just a')
# Out:
#                            Seniors  Juniors  Sophomores  Freshmen  coltot
# Freshman/Sophomore year         29       44          25        11     109
# Elementary school                9       10          13         7      40
# Middle/Junior high school       25       25          17        20      88
# Junior/Senior year              42       23           0         1      66
# Never                          380      550         596       680    2209
# rowtot                         485      652         651       719    2512

# %% [markdown]
# #### Had more than a sip or two of beer, wine, or hard liquor? (e.g.vodka, whiskey or gin)?

# %%
firstusegrade('Had more than a sip or two of b')
# Out:
#                            Seniors  Juniors  Sophomores  Freshmen  coltot
# Freshman/Sophomore year        152      208         150        66     576
# Elementary school               24       31          27        31     114
# Middle/Junior high school       58      109         102       134     404
# Junior/Senior year              79       44           1         1     125
# Never                          173      265         376       492    1309
# rowtot                         486      657         656       724    2528

# %% [markdown]
# #### Began drinking alcoholic beverages regularly, that is, atleast once or twice a month?

# %%
firstusegrade('Began drinking alcoholic bevera')
# Out:
#                            Seniors  Juniors  Sophomores  Freshmen  coltot
# Freshman/Sophomore year         78      100          83        40     301
# Elementary school                7        1           4         3      16
# Middle/Junior high school       12       16          16        24      69
# Junior/Senior year             101       50           0         2     153
# Never                          290      489         553       656    1991
# rowtot                         488      656         656       725    2530

# %%
def rxsources(name):
    name=pd.crosstab(index=wb[name],columns=wb['Year'],margins=True)
    name=name.drop(['Class of 2019 and earlier'], axis=1)
    name.columns=['Seniors','Juniors','Sophomores','Freshmen','coltot']
    name.index=['No','Yes','rowtot']

   
    display(name)

# %% [markdown]
# ## Q79 In the past year, did you get prescription drugs not prescribed to you from any of the following sources?

# %% [markdown]
# #### I bought them from someone

# %%
rxsources('I bought them from someone')
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          454      624         626       691    2398
# Yes          33       33          30        31     129
# rowtot      487      657         656       722    2527

# %% [markdown]
# #### I took them from home without the knowledge of my parents/guardians

# %%
rxsources('I took them from home without t')
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          468      625         636       693    2426
# Yes          19       31          19        30     100
# rowtot      487      656         655       723    2526

# %% [markdown]
# #### I took them from someone else's home

# %%
rxsources('I took them from someone else_s')
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          469      635         645       696    2449
# Yes          16       21          10        26      74
# rowtot      485      656         655       722    2523

# %% [markdown]
# #### My parent(s)/guardian(s) gave them to me

# %%
rxsources('My parent(s)/guardian(s) gave t')
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          468      624         634       679    2409
# Yes          19       32          22        44     118
# rowtot      487      656         656       723    2527

# %% [markdown]
# #### Someone other than my parent(s)/guardian(s) gave them to me

# %%
rxsources('Someone other than my parent(s)')
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          459      623         632       689    2406
# Yes          26       30          22        30     110
# rowtot      485      653         654       719    2516

# %%
def tobsources(name):
    name=pd.crosstab(index=wb[name],columns=wb['Year'],margins=True)
    name=name.drop(['Class of 2019 and earlier'], axis=1)
    name.columns=['Seniors','Juniors','Sophomores','Freshmen','coltot']
    name.index=['No','Yes','rowtot']

   
    display(name)

# %% [markdown]
# ## Q80 In the past year, did you get any tobacco or vaping products from the following sources?

# %% [markdown]
# #### I bought them at a gas station, store or mall

# %%
tobsources('I bought them at a gas station,')
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          403      583         603       685    2277
# Yes          85       72          54        33     246
# rowtot      488      655         657       718    2523

# %% [markdown]
# #### I gave a stranger money to buy them for me

# %%
tobsources('I gave a stranger money to buy')
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          466      634         633       701    2437
# Yes          21       22          20        18      83
# rowtot      487      656         653       719    2520

# %% [markdown]
# #### A friend gave them to me

# %%
tobsources('A friend gave them to me')
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          384      524         551       650    2112
# Yes         104      129         104        69     408
# rowtot      488      653         655       719    2520

# %% [markdown]
# #### My older brother or sister gave them to me

# %%
tobsources('My older brother or sister gave')
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          465      629         631       705    2434
# Yes          20       26          25        11      83
# rowtot      485      655         656       716    2517

# %% [markdown]
# #### My parent(s)/ guardian(s) gave them to me

# %%
tobsources('My parent(s)/ guardian(s) gave')
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          477      643         652       710    2486
# Yes          10       10           5         9      35
# rowtot      487      653         657       719    2521

# %% [markdown]
# #### I took them from a store

# %%
tobsources('I took them from a store')
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          474      642         647       709    2476
# Yes          13       13           9         9      45
# rowtot      487      655         656       718    2521

# %% [markdown]
# #### I took them from home without my parent(s)/guardian(s) knowing it

# %%
tobsources('I took them from home without m')
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          474      639         642       700    2459
# Yes          13       17          12        17      60
# rowtot      487      656         654       717    2519

# %% [markdown]
# #### I bought them online

# %%
tobsources('I bought them online')
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          446      618         621       699    2388
# Yes          17       13          17         9      57
# rowtot      463      631         638       708    2445

# %%
def cansources(name):
    name=pd.crosstab(index=wb[name],columns=wb['Year'],margins=True)
    name=name.drop(['Class of 2019 and earlier'], axis=1)
    name.columns=['Seniors','Juniors','Sophomores','Freshmen','coltot']
    name.index=['No','Yes','rowtot']

   
    display(name)

# %% [markdown]
# ## Q81 In the past year, did you get your own cannabis (marijuana) from any of the following sources?

# %% [markdown]
# #### A friend gave it to me

# %%
cansources('A friend gave it to me')
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          287      439         508       630    1867
# Yes         199      216         148        86     651
# rowtot      486      655         656       716    2518

# %% [markdown]
# #### My parent(s)/ guardian(s) with their permission

# %%
cansources('My parent(s)/ guardian(s) with')
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          463      629         644       709    2449
# Yes          22       24          11         9      67
# rowtot      485      653         655       718    2516

# %% [markdown]
# #### My parent(s)/ guardian(s) without their permission

# %%
cansources('My parent(s)/ guardian(s) witho')
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          456      615         631       700    2406
# Yes          30       36          25        18     110
# rowtot      486      651         656       718    2516

# %% [markdown]
# #### My older brother or sister gave it to me

# %%
cansources('My older brother or sister ga_1')
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          442      601         619       696    2362
# Yes          41       50          36        19     147
# rowtot      483      651         655       715    2509

# %% [markdown]
# #### I bought it from someone who sells drugs

# %%
cansources('I bought it from someone who se')
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          367      517         564       670    2121
# Yes         119      138          90        47     396
# rowtot      486      655         654       717    2517

# %% [markdown]
# #### An adult other than parent(s)/guardian(s) with that adults' permission

# %%
cansources('An adult other than parent(s)/g')
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          463      639         644       698    2448
# Yes          23       15          12        19      70
# rowtot      486      654         656       717    2518

# %% [markdown]
# #### I took it form someone else's home

# %%
cansources('I took it form someone else_s h')
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          470      641         641       704    2460
# Yes          14       13          10        12      50
# rowtot      484      654         651       716    2510

# %% [markdown]
# #### I gave a stranger money to buy it for me

# %%
cansources('I gave a stranger money to bu_1')
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          468      637         635       702    2445
# Yes          15       12          13        15      57
# rowtot      483      649         648       717    2502

# %%
def alcsources(name):
    name=pd.crosstab(index=wb[name],columns=wb['Year'],margins=True)
    name=name.drop(['Class of 2019 and earlier'], axis=1)
    name.columns=['Seniors','Juniors','Sophomores','Freshmen','coltot']
    name.index=['No','Yes','rowtot']

   
    display(name)

# %% [markdown]
# ## Q82 In the past year, did you get your own beer, wine or liquor from the following sources?

# %% [markdown]
# #### I bought it at a gas station or store

# %%
alcsources('I bought it at a gas station or')
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          425      614         643       705    2390
# Yes          62       43          11        14     132
# rowtot      487      657         654       719    2522

# %% [markdown]
# #### I bought it at a bar or restaurant

# %%
alcsources('I bought it at a bar or restaur')
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          440      615         637       709    2404
# Yes          47       39          19        10     117
# rowtot      487      654         656       719    2521

# %% [markdown]
# #### I gave a stranger money to buy it for me

# %%
alcsources('I gave a stranger money to bu_2')
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          465      634         638       709    2449
# Yes          20       19          16         9      66
# rowtot      485      653         654       718    2515

# %% [markdown]
# #### A friend gave it to me

# %%
alcsources('A friend gave it to me_1')
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          292      455         532       645    1927
# Yes         196      197         122        72     589
# rowtot      488      652         654       717    2516

# %% [markdown]
# #### My older brother or sister gave it to me

# %%
alcsources('My older brother or sister ga_2')
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          427      576         612       681    2300
# Yes          59       73          36        34     203
# rowtot      486      649         648       715    2503

# %% [markdown]
# #### My parent(s)/ guardian(s) WITH their permission

# %%
alcsources('My parent(s)/ guardian(s) WIT_1')
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          366      513         556       620    2059
# Yes         119      141         100        97     458
# rowtot      485      654         656       717    2517

# %% [markdown]
# #### My parent(s)/guardian(s) WITHOUT their permission

# %%
alcsources('My parent(s)/guardian(s) WITHOU')
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          410      569         588       671    2242
# Yes          76       85          66        48     276
# rowtot      486      654         654       719    2518

# %% [markdown]
# #### An adult (other than parent(s)/guardian(s)) WITH that adults' permission

# %%
alcsources('An adult (other than parent(s)/')
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          415      582         612       674    2287
# Yes          70       72          42        43     228
# rowtot      485      654         654       717    2515

# %% [markdown]
# #### An adult (other than parent(s)/guardian(s)) WITHOUT that adults' permission

# %%
alcsources('An adult (other than parent(s_1')
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          456      616         633       693    2402
# Yes          31       36          23        24     115
# rowtot      487      652         656       717    2517

# %% [markdown]
# #### I took it from a store

# %%
alcsources('I took it from a store')
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          471      628         632       705    2440
# Yes          16       25          21        10      73
# rowtot      487      653         653       715    2513

# %% [markdown]
# #### I got it at a party

# %%
alcsources('I got it at a party')
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          290      444         512       640    1889
# Yes         199      210         143        76     630
# rowtot      489      654         655       716    2519

# %% [markdown]
# ###  Q83 How easy do you think it is to become addicted to substances such as alcohol, drugs, tobacco, e-cigarettes, etc.? (Yellow) + Q84 How easy do you think it is to recover from an addiction to substances such as alcohol, drugs, tobacco, e-cigarettes, etc.? (Cyan)

# %%
wb['Ease of addiction'].dropna().astype(int).hist(alpha=0.5, color='y')
wb['Ease of recovery'].dropna().astype(int).hist(alpha=0.5, color='c')
# Out:
# <AxesSubplot:>

# %%
def healthconseq(name):
    name=pd.crosstab(index=wb[name],columns=wb['Year'],margins=True)
    name=name.drop(['Class of 2019 and earlier'], axis=1)
    name.columns=['Seniors','Juniors','Sophomores','Freshmen','coltot']
    name.index=['A little','Extremely likely','Moderately','Not at all','Quite likely','rowtot']
    name=name.reindex(['Not at all','A little','Moderately','Quite likely','Extremely likely','rowtot'])
    
    display(name)

# %% [markdown]
# ## Q85 How likely do you think it would be for the following health consequences to happen to you as a result of using substances such as alcohol, cannabis/marijuana, e-cigarettes, etc.?

# %% [markdown]
# #### Physical impacts such as blacking out, getting alcohol poisoning, overdosing, etc.

# %%
healthconseq('Physical impacts such as blacki')
# Out:
#                   Seniors  Juniors  Sophomores  Freshmen  coltot
# Not at all            106      174         150       165     598
# A little              115      120         116       114     466
# Moderately            123      166         166       156     611
# Quite likely           93      134         139       194     561
# Extremely likely       47       59          82        87     275
# rowtot                484      653         653       716    2511

# %% [markdown]
# #### Engaging in risky sexual behavior

# %%
healthconseq('Engaging in risky sexual behavi')
# Out:
#                   Seniors  Juniors  Sophomores  Freshmen  coltot
# Not at all            118      171         177       181     650
# A little               96      114         109       105     425
# Moderately            121      162         164       155     602
# Quite likely           93      147         135       177     553
# Extremely likely       56       58          69        96     279
# rowtot                484      652         654       714    2509

# %% [markdown]
# #### Becoming addicted

# %%
healthconseq('Becoming addicted')
# Out:
#                   Seniors  Juniors  Sophomores  Freshmen  coltot
# Not at all            132      162         146       159     602
# A little               87      102          88        69     347
# Moderately            101      143         136       108     488
# Quite likely           93      138         154       191     577
# Extremely likely       66      100         124       182     472
# rowtot                479      645         648       709    2486

# %% [markdown]
# #### Becoming paranoid or anxious

# %%
healthconseq('Becoming paranoid or anxious')
# Out:
#                   Seniors  Juniors  Sophomores  Freshmen  coltot
# Not at all            105      141         132       147     528
# A little               77      112         101        85     376
# Moderately            133      142         143       147     565
# Quite likely          105      166         160       206     638
# Extremely likely       63       88         114       130     395
# rowtot                483      649         650       715    2502

# %% [markdown]
# #### Being victimized (e.g., robbed, hurt, raped, etc.)

# %%
healthconseq('Being victimized (e.g., robbed,')
# Out:
#                   Seniors  Juniors  Sophomores  Freshmen  coltot
# Not at all            136      210         184       195     728
# A little              109      147         138       134     529
# Moderately            115      141         160       185     601
# Quite likely           79       98          89       119     386
# Extremely likely       45       55          82        83     265
# rowtot                484      651         653       716    2509

# %%
def legconseq(name):
    name=pd.crosstab(index=wb[name],columns=wb['Year'],margins=True)
    name=name.drop(['Class of 2019 and earlier'], axis=1)
    name.columns=['Seniors','Juniors','Sophomores','Freshmen','coltot']
    name.index=['A little','Extremely likely','Moderately','Not at all','Quite likely','rowtot']
    name=name.reindex(['Not at all','A little','Moderately','Quite likely','Extremely likely','rowtot'])
    
    display(name)

# %% [markdown]
# ### Q86 How likely do you think it would be for the following social or legal consequences to happen to you as a result of using substances such as alcohol, cannabis/marijuana, e-cigarettes, etc.?

# %% [markdown]
# #### Getting into a verbal or physical altercation (fight)

# %%
legconseq('Getting into a verbal or physic')
# Out:
#                   Seniors  Juniors  Sophomores  Freshmen  coltot
# Not at all            173      226         220       190     812
# A little              112      149         111       134     506
# Moderately             92      133         147       169     541
# Quite likely           62      100         117       143     424
# Extremely likely       42       43          54        81     220
# rowtot                481      651         649       717    2503

# %% [markdown]
# #### Losing eligibility to participate in school sports and activities

# %%
legconseq('Losing eligibility to participa')
# Out:
#                   Seniors  Juniors  Sophomores  Freshmen  coltot
# Not at all            167      227         176       163     736
# A little               87      110          92        79     368
# Moderately             87      124         127       123     461
# Quite likely           80      112         148       170     512
# Extremely likely       60       78         106       181     425
# rowtot                481      651         649       716    2502

# %% [markdown]
# #### Getting arrested or imprisoned

# %%
legconseq('Getting arrested or imprisoned')
# Out:
#                   Seniors  Juniors  Sophomores  Freshmen  coltot
# Not at all            181      268         221       201     874
# A little              115      137         148       153     553
# Moderately             86      120         129       142     477
# Quite likely           51       77          88       126     344
# Extremely likely       48       47          61        93     249
# rowtot                481      649         647       715    2497

# %% [markdown]
# #### Getting in trouble with your parent(s)/guardian(s)

# %%
legconseq('Getting in trouble with your pa')
# Out:
#                   Seniors  Juniors  Sophomores  Freshmen  coltot
# Not at all             87      136         113       115     454
# A little               86       75          82        51     294
# Moderately            123      141         110        93     467
# Quite likely          104      160         156       176     598
# Extremely likely       82      137         187       280     686
# rowtot                482      649         648       715    2499

# %% [markdown]
# #### Damaging friendships or relationships

# %%
legconseq('Damaging friendships or relatio')
# Out:
#                   Seniors  Juniors  Sophomores  Freshmen  coltot
# Not at all            148      202         175       159     687
# A little              107      153         111       117     488
# Moderately            108      122         144       138     512
# Quite likely           70       98         140       154     464
# Extremely likely       47       76          79       146     348
# rowtot                480      651         649       714    2499

# %%
def belsources(name):
    name=pd.crosstab(index=wb[name],columns=wb['Year'],margins=True)
    name=name.drop(['Class of 2019 and earlier'], axis=1)
    name.columns=['Seniors','Juniors','Sophomores','Freshmen','coltot']
    name=name.reindex(['Not at all','A little','Moderately','very much','Completely','All'])
    
    display(name)

# %% [markdown]
# ## Q87 How believable are the following sources of information about alcohol and drugs?

# %% [markdown]
# #### ETHS School Based Health Center

# %%
belsources('ETHS School Based Health Center')
# Out:
#                                  Seniors  Juniors  Sophomores  Freshmen  \
# ETHS School Based Health Center
# Not at all                          46.0     75.0        46.0      60.0
# A little                            52.0     66.0        53.0      54.0
# Moderately                         113.0    170.0       152.0     152.0
# very much                            NaN      NaN         NaN       NaN
# Completely                         105.0    128.0       167.0     197.0
# All                                476.0    651.0       654.0     713.0
#
#                                  coltot
# ETHS School Based Health Center
# Not at all                        229.0
# A little                          225.0
# Moderately                        588.0
# very much                           NaN
# Completely                        598.0
# All                              2499.0

# %% [markdown]
# #### ETHS school nurse

# %%
belsources('ETHS school nurse')
# Out:
#                    Seniors  Juniors  Sophomores  Freshmen  coltot
# ETHS school nurse
# Not at all            53.0     91.0        53.0      74.0   273.0
# A little              80.0     86.0        70.0      71.0   307.0
# Moderately           119.0    176.0       174.0     186.0   656.0
# very much              NaN      NaN         NaN       NaN     NaN
# Completely            83.0    101.0       134.0     167.0   486.0
# All                  475.0    651.0       654.0     714.0  2499.0

# %% [markdown]
# #### Wellness teacher

# %%
belsources('Wellness teacher')
# Out:
#                   Seniors  Juniors  Sophomores  Freshmen  coltot
# Wellness teacher
# Not at all           41.0     71.0        44.0      70.0   228.0
# A little             73.0     83.0        58.0      73.0   287.0
# Moderately          131.0    182.0       185.0     178.0   677.0
# very much             NaN      NaN         NaN       NaN     NaN
# Completely           75.0     98.0       128.0     137.0   439.0
# All                 472.0    645.0       647.0     696.0  2465.0

# %% [markdown]
# #### Other teacher

# %%
belsources('Other teacher')
# Out:
#                Seniors  Juniors  Sophomores  Freshmen  coltot
# Other teacher
# Not at all        67.0     94.0        75.0      96.0   334.0
# A little          98.0    144.0       142.0     174.0   558.0
# Moderately       175.0    251.0       259.0     263.0   949.0
# very much          NaN      NaN         NaN       NaN     NaN
# Completely        44.0     47.0        45.0      57.0   194.0
# All              474.0    647.0       640.0     705.0  2471.0

# %% [markdown]
# #### School social worker/counselor/psychologist

# %%
belsources('School social worker/counselor/')
# Out:
#                                  Seniors  Juniors  Sophomores  Freshmen  \
# School social worker/counselor/
# Not at all                          55.0     76.0        59.0      71.0
# A little                            67.0     78.0        68.0      91.0
# Moderately                         129.0    186.0       191.0     192.0
# very much                            NaN      NaN         NaN       NaN
# Completely                          75.0     94.0       127.0     125.0
# All                                473.0    648.0       653.0     713.0
#
#                                  coltot
# School social worker/counselor/
# Not at all                        263.0
# A little                          304.0
# Moderately                        699.0
# very much                           NaN
# Completely                        422.0
# All                              2492.0

# %% [markdown]
# #### Coach

# %%
belsources('Coach')
# Out:
#             Seniors  Juniors  Sophomores  Freshmen  coltot
# Coach
# Not at all     68.0    100.0        74.0      88.0   332.0
# A little      120.0    133.0       111.0     127.0   491.0
# Moderately    144.0    224.0       242.0     250.0   861.0
# very much       NaN      NaN         NaN       NaN     NaN
# Completely     47.0     57.0        71.0      79.0   255.0
# All           470.0    646.0       651.0     708.0  2480.0

# %% [markdown]
# #### Club sponsor/arts director

# %%
belsources('Club sponsor/arts director')
# Out:
#                             Seniors  Juniors  Sophomores  Freshmen  coltot
# Club sponsor/arts director
# Not at all                     88.0    121.0        94.0     128.0   433.0
# A little                      121.0    153.0       142.0     177.0   593.0
# Moderately                    140.0    224.0       245.0     232.0   842.0
# very much                       NaN      NaN         NaN       NaN     NaN
# Completely                     38.0     49.0        49.0      58.0   195.0
# All                           470.0    647.0       645.0     704.0  2471.0

# %% [markdown]
# #### Safety staff

# %%
belsources('Safety staff')
# Out:
#               Seniors  Juniors  Sophomores  Freshmen  coltot
# Safety staff
# Not at all       94.0    128.0        88.0     108.0   420.0
# A little        111.0    145.0       138.0     147.0   541.0
# Moderately      153.0    222.0       244.0     241.0   861.0
# very much         NaN      NaN         NaN       NaN     NaN
# Completely       41.0     46.0        53.0      72.0   213.0
# All             474.0    649.0       650.0     709.0  2487.0

# %% [markdown]
# #### Dean

# %%
belsources('Dean')
# Out:
#             Seniors  Juniors  Sophomores  Freshmen  coltot
# Dean
# Not at all    102.0    127.0        75.0     102.0   408.0
# A little      107.0    109.0        98.0     115.0   429.0
# Moderately    130.0    206.0       220.0     215.0   772.0
# very much       NaN      NaN         NaN       NaN     NaN
# Completely     49.0     61.0        92.0      99.0   302.0
# All           475.0    647.0       652.0     710.0  2489.0

# %% [markdown]
# #### Evanstonian

# %%
belsources('Evanstonian')
# Out:
#              Seniors  Juniors  Sophomores  Freshmen  coltot
# Evanstonian
# Not at all      98.0    132.0       118.0     145.0   495.0
# A little       120.0    136.0       128.0     184.0   568.0
# Moderately     132.0    210.0       219.0     222.0   784.0
# very much        NaN      NaN         NaN       NaN     NaN
# Completely      39.0     49.0        52.0      57.0   198.0
# All            470.0    647.0       648.0     708.0  2478.0

# %% [markdown]
# #### Tinkle Times/bathroom poster

# %%
belsources('Tinkle Times/bathroom poster')
# Out:
#                               Seniors  Juniors  Sophomores  Freshmen  coltot
# Tinkle Times/bathroom poster
# Not at all                      107.0    157.0       138.0     212.0   616.0
# A little                        108.0    145.0       139.0     168.0   560.0
# Moderately                      125.0    194.0       208.0     193.0   721.0
# very much                         NaN      NaN         NaN       NaN     NaN
# Completely                       46.0     47.0        52.0      46.0   192.0
# All                             473.0    647.0       649.0     711.0  2485.0

# %% [markdown]
# #### Parent/Guardian

# %%
belsources('Parent/Guardian')
# Out:
#                  Seniors  Juniors  Sophomores  Freshmen  coltot
# Parent/Guardian
# Not at all          43.0     58.0        46.0      57.0   206.0
# A little            70.0     80.0        75.0      77.0   302.0
# Moderately         114.0    186.0       195.0     190.0   686.0
# very much            NaN      NaN         NaN       NaN     NaN
# Completely          90.0    107.0       138.0     165.0   501.0
# All                474.0    648.0       650.0     707.0  2484.0

# %% [markdown]
# #### Other Family Member

# %%
belsources('Other Family Member')
# Out:
#                      Seniors  Juniors  Sophomores  Freshmen  coltot
# Other Family Member
# Not at all              49.0     70.0        56.0      71.0   248.0
# A little                91.0     95.0       105.0     100.0   391.0
# Moderately             134.0    217.0       207.0     252.0   811.0
# very much                NaN      NaN         NaN       NaN     NaN
# Completely              72.0     75.0       102.0     132.0   382.0
# All                    468.0    636.0       646.0     709.0  2464.0

# %% [markdown]
# #### Friend

# %%
belsources('Friend')
# Out:
#             Seniors  Juniors  Sophomores  Freshmen  coltot
# Friend
# Not at all     65.0     86.0        79.0      95.0   327.0
# A little      113.0    145.0       196.0     215.0   669.0
# Moderately    154.0    230.0       209.0     221.0   815.0
# very much       NaN      NaN         NaN       NaN     NaN
# Completely     47.0     52.0        49.0      66.0   215.0
# All           471.0    647.0       652.0     710.0  2485.0

# %% [markdown]
# #### Police Officer

# %%
belsources('Police Officer')
# Out:
#                 Seniors  Juniors  Sophomores  Freshmen  coltot
# Police Officer
# Not at all         66.0     93.0        57.0      79.0   297.0
# A little           64.0     66.0        47.0      59.0   236.0
# Moderately        123.0    177.0       171.0     138.0   610.0
# very much           NaN      NaN         NaN       NaN     NaN
# Completely         92.0    124.0       173.0     217.0   607.0
# All               472.0    646.0       650.0     708.0  2481.0

# %% [markdown]
# #### Internet

# %%
belsources('Internet')
# Out:
#             Seniors  Juniors  Sophomores  Freshmen  coltot
# Internet
# Not at all     67.0     81.0        81.0     141.0   372.0
# A little       82.0    125.0       131.0     182.0   520.0
# Moderately    142.0    217.0       235.0     209.0   804.0
# very much       NaN      NaN         NaN       NaN     NaN
# Completely     54.0     69.0        70.0      59.0   253.0
# All           472.0    650.0       651.0     705.0  2483.0

# %% [markdown]
# ## Q88 Have you ever been offered, given, bought or sold drugs at school?

# %%
offeredorsold=pd.crosstab(index=wb['O,g,b,s drugs at school'],columns=wb['Year'],margins=True)
offeredorsold=offeredorsold.drop(['Class of 2019 and earlier'], axis=1)
offeredorsold.columns=['Seniors','Juniors','Sophomores','Freshmen','coltot']
offeredorsold.index=['No','Yes','rowtot']
offeredorsold
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          334      416         467       550    1771
# Yes         154      238         189       171     753
# rowtot      488      654         656       721    2524

# %%
bathroom=pd.crosstab(index=wb['Bathroom'],columns=wb['Year'])
stairwell=pd.crosstab(index=wb['Stairwell'],columns=wb['Year'])
plot=pd.crosstab(index=wb['Parking lot'],columns=wb['Year'])
classroom=pd.crosstab(index=wb['Classroom'],columns=wb['Year'])
lockerpe=pd.crosstab(index=wb['Locker room/PE wing'],columns=wb['Year'])
sencourt=pd.crosstab(index=wb['Pneumonia Alley/Senior Courtyar'],columns=wb['Year'])
lunchr=pd.crosstab(index=wb['Lunchroom/cafeteria/study cafe'],columns=wb['Year'])
hub=pd.crosstab(index=wb['The HUB'],columns=wb['Year'])
libtech=pd.crosstab(index=wb['Library/tech center/study cente'],columns=wb['Year'])
artmus=pd.crosstab(index=wb['Art wing/Music wing'],columns=wb['Year'])
audi=pd.crosstab(index=wb['Auditorium'],columns=wb['Year'])
otherprop=pd.crosstab(index=wb['Other place on school property'],columns=wb['Year'])
hallway=pd.crosstab(index=wb['Hallway'],columns=wb['Year'])  

drugloccoltots=pd.DataFrame({"Seniors":[516],"Juniors":[743],"Sophomores":[541],"Freshmen":[382],"Class of 2019 and earlier":[0]})

# %% [markdown]
# ## Q89 In which of the following locations have you been offered, given, bought or sold drugs at school? Check all that apply.

# %%
drugloc_stack = pd.concat([bathroom,stairwell,plot,classroom,lockerpe,lunchr,hub,libtech,artmus,audi,otherprop,hallway], axis=0)
drugloc_stack=drugloc_stack.drop(['Class of 2019 and earlier'], axis=1)
drugloc_stack.columns=['Seniors','Juniors','Sophomores','Freshmen']
drugloc_stack
drugloc_stack2=pd.concat([drugloc_stack, drugloccoltots], axis=0)
drugloc_stack2=drugloc_stack2.drop(['Class of 2019 and earlier'], axis=1)
drugloc_stack2
# Out:
#                                   Seniors  Juniors  Sophomores  Freshmen
# Bathroom                               92      122         115        80
# Stairwell                              35       43          35        28
# Parking lot                            47       67          38        13
# Classroom                              57       81          54        52
# Locker room/PE wing                    40       61          49        27
# Lunchroom/cafeteria/study cafe         48       74          57        44
# The HUB                                49       54          23        13
# Library/tech center/study center       18       27          10        11
# Art wing/Music wing                    15       37          22        12
# Auditorium                             12       21          13         9
# Other place on school property         36       66          52        46
# Hallway                                67       90          73        47
# ...

# %% [markdown]
# # Q90 Have you ever used drugs at school?

# %%
usedatschool=pd.crosstab(index=wb['Used at school?'],columns=wb['Year'],margins=True)
usedatschool=usedatschool.drop(['Class of 2019 and earlier'], axis=1)
usedatschool.columns=['Seniors','Juniors','Sophomores','Freshmen','coltot']
usedatschool.index=['No','Yes','rowtot']
usedatschool
# Out:
#         Seniors  Juniors  Sophomores  Freshmen  coltot
# No          403      554         577       673    2210
# Yes          86      104          78        51     321
# rowtot      489      658         655       724    2531

# %% [markdown]
# ## Q91 In which of the following locations have youused drugs at school? Check all that apply.

# %%
bathroomuse=pd.crosstab(index=wb['Bathroom_1'],columns=wb['Year'])
stairwelluse=pd.crosstab(index=wb['Stairwell_1'],columns=wb['Year'])
plotuse=pd.crosstab(index=wb['Parking lot_1'],columns=wb['Year'])
classroomuse=pd.crosstab(index=wb['Classroom_1'],columns=wb['Year'])
lockerpeuse=pd.crosstab(index=wb['Locker room/PE wing_1'],columns=wb['Year'])
sencourtuse=pd.crosstab(index=wb['Pneumonia Alley/Senior Courty_1'],columns=wb['Year'])
lunchruse=pd.crosstab(index=wb['Lunchroom/cafeteria/study caf_1'],columns=wb['Year'])
hubuse=pd.crosstab(index=wb['The HUB_1'],columns=wb['Year'])
libtechuse=pd.crosstab(index=wb['Library/tech center/study cen_1'],columns=wb['Year'])
artmususe=pd.crosstab(index=wb['Art wing/Music wing_1'],columns=wb['Year'])
audiuse=pd.crosstab(index=wb['Auditorium_1'],columns=wb['Year'])
otherpropuse=pd.crosstab(index=wb['Other place on school propert_1'],columns=wb['Year'])
hallwayuse=pd.crosstab(index=wb['Hallway_1'],columns=wb['Year'])  
druglocusecoltots=pd.DataFrame({"Seniors":[312],"Juniors":[352],"Sophomores":[247],"Freshmen":[160]})

druglocuse_stack = pd.concat([bathroomuse,stairwelluse,plotuse,classroomuse,lockerpeuse,lunchruse,hubuse,libtechuse,artmususe,audiuse,otherpropuse,hallwayuse], axis=0)
druglocuse_stack=druglocuse_stack.drop(['Class of 2019 and earlier'], axis=1)
druglocuse_stack.columns=['Seniors','Juniors','Sophomores','Freshmen']
druglocuse_stack
druglocuse_stack2=pd.concat([druglocuse_stack, druglocusecoltots], axis=0)
druglocuse_stack2
# Out:
#                                   Seniors  Juniors  Sophomores  Freshmen
# Bathroom                               67       69          58        36
# Stairwell                              22       27          14        10
# Parking lot                            28       25          21         8
# Classroom                              34       43          23        12
# Locker room/PE wing                    25       28          19         9
# Lunchroom/cafeteria/study cafe         28       30          21        10
# The HUB                                27       27          14         4
# Library/tech center/study center       13       14           9         2
# Art wing/Music wing                    11       17          19         3
# Auditorium                             14       17           9         4
# Other place on school property         22       29          21        14
# Hallway                                21       26          19         8
# ...

# %%
def freqofsit(name):
    name=pd.crosstab(index=wb[name],columns=wb['Year'],margins=True)
    name=name.drop(['Class of 2019 and earlier'], axis=1)
    name.columns=['Seniors','Juniors','Sophomores','Freshmen','coltot']
    name.index=['Always/almost always','Never','Often','Rarely','Sometimes','rowtot']
    name=name.reindex(['Never','Rarely','Sometimes','Often','Always/almost always','rowtot'])
   
    display(name)

# %% [markdown]
# ## Q92 How often do you think the following situations involving the use of alcohol and/or drugs happen at ETHS?

# %% [markdown]
# #### It is easy to get alcohol or drugs in school

# %%
freqofsit('It is easy to get alcohol or dr')
# Out:
#                       Seniors  Juniors  Sophomores  Freshmen  coltot
# Never                      62       88          76        99     327
# Rarely                     63       83         104       141     392
# Sometimes                 169      212         215       232     828
# Often                     130      171         172       184     657
# Always/almost always       60       96          85        61     304
# rowtot                    484      650         652       717    2508

# %% [markdown]
# #### It is easy to use in school without getting caught

# %%
freqofsit('It is easy to use in school wit')
# Out:
#                       Seniors  Juniors  Sophomores  Freshmen  coltot
# Never                      54       76          66        98     297
# Rarely                     53       92         107       151     403
# Sometimes                 192      225         229       235     881
# Often                     129      157         183       176     645
# Always/almost always       57      101          66        58     284
# rowtot                    485      651         651       718    2510

# %% [markdown]
# #### School staff know when students are under the influence

# %%
freqofsit('School staff know when students')
# Out:
#                       Seniors  Juniors  Sophomores  Freshmen  coltot
# Never                      57       76          64        81     281
# Rarely                    121      200         163       156     640
# Sometimes                 218      245         301       312    1076
# Often                      66      100         102       124     393
# Always/almost always       22       28          22        44     117
# rowtot                    484      649         652       717    2507

# %% [markdown]
# #### School staff offer support to students who have been using

# %%
freqofsit('School staff offer support to s')
# Out:
#                       Seniors  Juniors  Sophomores  Freshmen  coltot
# Never                     109      167         121       131     531
# Rarely                    143      194         194       172     703
# Sometimes                 147      163         190       200     700
# Often                      55       84         109       135     384
# Always/almost always       28       43          37        78     187
# rowtot                    482      651         651       716    2505

# %% [markdown]
# #### School staff report when students are under the influence

# %%
freqofsit('School staff report when studen')
# Out:
#                       Seniors  Juniors  Sophomores  Freshmen  coltot
# Never                      56       88          62        75     284
# Rarely                     91      127         101        98     417
# Sometimes                 168      184         195       195     742
# Often                     112      137         172       172     593
# Always/almost always       54      112         118       176     462
# rowtot                    481      648         648       716    2498

# %%
def trueatschool(name):
    name=pd.crosstab(index=wb[name],columns=wb['Year'],margins=True)
    name=name.drop(['Class of 2019 and earlier'], axis=1)
    name.columns=['Seniors','Juniors','Sophomores','Freshmen','coltot']
    name.index=['Always/almost always true','Never or almost never true','Often true','Rarely true','Sometimes true','rowtot']
    name=name.reindex(['Never or almost never true','Rarely true','Sometimes true','Often true','Always/almost always true','rowtot'])
   
    display(name)

# %% [markdown]
# ## Q93 How true are the following statements regarding alcohol and/or drug use at school?

# %% [markdown]
# #### Students are treated fairly

# %%
trueatschool('Students are treated fairly')
# Out:
#                             Seniors  Juniors  Sophomores  Freshmen  coltot
# Never or almost never true       65       68          48        63     246
# Rarely true                      94      126          99        99     419
# Sometimes true                  195      269         285       289    1039
# Often true                       95      139         170       205     609
# Always/almost always true        31       39          48        54     173
# rowtot                          480      641         650       710    2486

# %% [markdown]
# #### Deans always enforce the school rules

# %%
trueatschool('Deans always enforce the school')
# Out:
#                             Seniors  Juniors  Sophomores  Freshmen  coltot
# Never or almost never true       38       43          25        43     150
# Rarely true                      31       56          43        53     184
# Sometimes true                  164      186         197       163     710
# Often true                      152      217         242       262     874
# Always/almost always true        96      138         143       186     565
# rowtot                          481      640         650       707    2483

# %% [markdown]
# #### Students respect school rules and/or administrators

# %%
trueatschool('Students respect school rules a')
# Out:
#                             Seniors  Juniors  Sophomores  Freshmen  coltot
# Never or almost never true       69       93          75        75     313
# Rarely true                     131      181         156       175     644
# Sometimes true                  206      259         305       308    1079
# Often true                       52       83          91       124     350
# Always/almost always true        22       25          21        27      97
# rowtot                          480      641         648       709    2483

# %% [markdown]
# #### Some groups are targeted while others are overlooked

# %%
trueatschool('Some groups are targeted while')
# Out:
#                             Seniors  Juniors  Sophomores  Freshmen  coltot
# Never or almost never true       41       50          52        72     216
# Rarely true                      39       77         101       133     352
# Sometimes true                  137      197         206       242     782
# Often true                      150      199         193       179     721
# Always/almost always true       112      119          93        82     408
# rowtot                          479      642         645       708    2479

# %% [markdown]
# #### Adults at my school care about my well-being

# %%
trueatschool('Adults at my school care about')
# Out:
#                             Seniors  Juniors  Sophomores  Freshmen  coltot
# Never or almost never true       42       53          38        52     187
# Rarely true                      47       85          73        89     295
# Sometimes true                  199      243         249       230     921
# Often true                      133      184         208       219     744
# Always/almost always true        58       76          81       117     334
# rowtot                          479      641         649       707    2481

# %%
def susproblem(name):
    name=pd.crosstab(index=wb[name],columns=wb['Year'])
    name=name.drop(['Class of 2019 and earlier'], axis=1)
    name.columns=['Seniors','Juniors','Sophomores','Freshmen']
    
    display(name)

# %% [markdown]
# ## Q94 How much of a problem would it be to get an in-school suspension as a result of using alcohol or drugs at ETHS?

# %%
susproblem('inschool_suspension_drug')
# Out:
#                           Seniors  Juniors  Sophomores  Freshmen
# inschool_suspension_drug
# A minor problem                41       69          54        53
# A moderate problem            127      162         158       162
# A serious problem             161      226         254       266
# A very serious problem        118      149         153       181
# Not a problem                  35       45          33        53

# %% [markdown]
# ## Q95 How much of a problem would it be to get an out-of-school suspension as a result of using alcohol or drugs at ETHS?

# %%
susproblem('outschool_suspension_drug')
# Out:
#                            Seniors  Juniors  Sophomores  Freshmen
# outschool_suspension_drug
# A minor problem                 24       47          38        25
# A moderate problem              79       99          99       107
# A serious problem              160      204         236       245
# A very serious problem         178      254         247       285
# Not a problem                   37       45          32        52

# %%
def parentalk(name):
    name=pd.crosstab(index=wb[name],columns=wb['Year'])
    name=name.drop(['Class of 2019 and earlier'], axis=1)
    name.columns=['Seniors','Juniors','Sophomores','Freshmen']
    
    display(name)

# %% [markdown]
# ## Q96 In the past year, have your parent(s)/guardian(s) talked to you about not using the following:

# %% [markdown]
# #### Tobacco (including e-cigarettes)

# %%
parentalk('Tobacco (including e-cigarettes')
# Out:
#                                  Seniors  Juniors  Sophomores  Freshmen
# Tobacco (including e-cigarettes
# No                                   191      199         184       182
# Yes                                  290      452         468       532

# %% [markdown]
# #### Alcohol

# %%
parentalk('Alcohol')
# Out:
#          Seniors  Juniors  Sophomores  Freshmen
# Alcohol
# No           200      229         185       205
# Yes          279      422         467       510

# %% [markdown]
# #### Cannabis (marijuana)

# %%
parentalk('Cannabis (marijuana)')
# Out:
#                       Seniors  Juniors  Sophomores  Freshmen
# Cannabis (marijuana)
# No                        180      202         181       189
# Yes                       299      449         472       526

# %% [markdown]
# #### Other substances (e.g., prescription drugs, painkillers, etc.)

# %%
parentalk('Other substances (e.g., prescri')
# Out:
#                                  Seniors  Juniors  Sophomores  Freshmen
# Other substances (e.g., prescri
# No                                   252      296         270       273
# Yes                                  227      353         382       441

# %% [markdown]
# ## Q97 Does your family have clear rules that do not allow alcohol and drug use for kids your age?

# %%
famrules=pd.crosstab(index=wb['Clear family rules'],columns=wb['Year'])
famrules=famrules.drop(['Class of 2019 and earlier'], axis=1)
famrules.columns=['Seniors','Juniors','Sophomores','Freshmen']
famrules
# Out:
#                     Seniors  Juniors  Sophomores  Freshmen
# Clear family rules
# No                      176      201         119       111
# Yes                     307      451         533       606

# %% [markdown]
# ## Q98 During the past 12 months, have you used tobacco, alcohol or drugs not prescribed to you?

# %%
yearuse=pd.crosstab(index=wb['Past year use any drug'],columns=wb['Year'])
yearuse=yearuse.drop(['Class of 2019 and earlier'], axis=1)
yearuse.columns=['Seniors','Juniors','Sophomores','Freshmen']
yearuse
# Out:
#                         Seniors  Juniors  Sophomores  Freshmen
# Past year use any drug
# No                          286      428         497       618
# Yes                         199      224         158        99

# %% [markdown]
# ## Q99 During the past 12 months, did you seek out support regarding your substance use?

# %%
yearsupport=pd.crosstab(index=wb['past year support seeking'],columns=wb['Year'])
yearsupport=yearsupport.drop(['Class of 2019 and earlier'], axis=1)
yearsupport.columns=['Seniors','Juniors','Sophomores','Freshmen']
yearsupport
# Out:
#                            Seniors  Juniors  Sophomores  Freshmen
# past year support seeking
# No                             195      217         148       104
# Yes                              7       15          12         9

# %%
def supportsources(name):
    name=pd.crosstab(index=wb[name],columns=wb['Year'])
    display(name)

# %%
ethstaff=pd.crosstab(index=wb['ETHS staff member'],columns=wb['Year'])
sapsw=pd.crosstab(index=wb['ETHS SAP School Social Worker'],columns=wb['Year'])
sro=pd.crosstab(index=wb['Police/school resource officer'],columns=wb['Year'])
parentg=pd.crosstab(index=wb['Parent/Guardian_1'],columns=wb['Year'])
famadult=pd.crosstab(index=wb['Adult family member'],columns=wb['Year'])
pcpo=pd.crosstab(index=wb['Primary Care Physician or other'],columns=wb['Year'])
therapistmh=pd.crosstab(index=wb['Therapist/Mental Health Profess'],columns=wb['Year'])

# %% [markdown]
# ## Q100 During the past 12 months, did you seek out support from any of the following regarding your substance use? Check all that apply.

# %%
support_stack = pd.concat([ethstaff,sapsw,sro,parentg,famadult,pcpo,therapistmh], axis=0)
support_stack.columns=['Seniors','Juniors','Sophomores','Freshmen']
support_stack
# Out:
#                                         Seniors  Juniors  Sophomores  Freshmen
# ETHS staff member                           1.0      1.0           4       4.0
# ETHS SAP School Social Worker               1.0      2.0           2       1.0
# Police/school resource officer              NaN      NaN           1       NaN
# Parent/Guardian                             2.0      9.0           6       5.0
# Adult family member                         3.0      4.0           4       3.0
# Primary Care Physician or other doctor      2.0      6.0           2       NaN
# Therapist/Mental Health Professional        5.0     11.0           5       2.0

# %%
supportsources('Other (please specify)_3')
# Out:
# Year                                                Class of 2020- Seniors  \
# Other (please specify)_3
# I hate ur fucking school and all the good you t...                       1
# Workers at PHP and Inpactient                                            0
# cousin                                                                   0
# friend                                                                   1
#
# Year                                                Class of 2021- Juniors  \
# Other (please specify)_3
# I hate ur fucking school and all the good you t...                       0
# Workers at PHP and Inpactient                                            1
# cousin                                                                   0
# friend                                                                   0
#
# Year                                                Class of 2022- Sophomores
# Other (please specify)_3
# ...

# %% [markdown]
# ## Q102 Do you think most ETHS students answered the questions on this survey honestly?

# %%
othershonest=pd.crosstab(index=wb['Were others honest?'],columns=wb['Year'])
othershonest=othershonest.drop(['Class of 2019 and earlier'], axis=1)
othershonest.columns=['Seniors','Juniors','Sophomores','Freshmen']
othershonest
# Out:
#                      Seniors  Juniors  Sophomores  Freshmen
# Were others honest?
# No                       292      419         384       398
# Yes                      200      242         275       331
